# %% [markdown]
# # Anomaly Detection
#
# In this exercise, you will implement the anomaly detection algorithm and apply it to detect failing servers on a network.
#
#
#
# # Outline
# - [ 1 - Packages ](#1)
# - [ 2 - Anomaly detection](#2)
#   - [ 2.1 Problem Statement](#2.1)
#   - [ 2.2  Dataset](#2.2)
#   - [ 2.3 Gaussian distribution](#2.3)
#     - [ Exercise 1](#ex01)
#     - [ Exercise 2](#ex02)
#   - [ 2.4 High dimensional dataset](#2.4)

# %% [markdown]
# _**NOTE:** To prevent errors from the autograder, you are not allowed to edit or delete non-graded cells in this lab. Please also refrain from adding any new cells.
# **Once you have passed this assignment** and want to experiment with any of the non-graded code, you may follow the instructions at the bottom of this notebook._

# %% [markdown]
# <a name="1"></a>
# ## 1 - Packages
#
# First, let's run the cell below to import all the packages that you will need during this assignment.
# - [numpy](www.numpy.org) is the fundamental package for working with matrices in Python.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
# - ``utils.py`` contains helper functions for this assignment. You do not need to modify code in this file.

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %matplotlib inline

# %% [markdown]
# <a name="2"></a>
# ## 2 - Anomaly detection
#
# <a name="2.1"></a>
# ### 2.1 Problem Statement
#
# In this exercise, you will implement an anomaly detection algorithm to
# detect anomalous behavior in server computers.
#
# The dataset contains two features -
#    * throughput (mb/s) and
#    * latency (ms) of response of each server.
#
# While your servers were operating, you collected $m=307$ examples of how they were behaving, and thus have an unlabeled dataset $\{x^{(1)}, \ldots, x^{(m)}\}$.
# * You suspect that the vast majority of these examples are “normal” (non-anomalous) examples of the servers operating normally, but there might also be some examples of servers acting anomalously within this dataset.
#
# You will use a Gaussian model to detect anomalous examples in your
# dataset.
# * You will first start on a 2D dataset that will allow you to visualize what the algorithm is doing.
# * On that dataset you will fit a Gaussian distribution and then find values that have very low probability and hence can be considered anomalies.
# * After that, you will apply the anomaly detection algorithm to a larger dataset with many dimensions.
#
# <a name="2.2"></a>
# ### 2.2  Dataset
#
# You will start by loading the dataset for this task.
# - The `load_data()` function shown below loads the data into the variables `X_train`, `X_val` and `y_val`
#     - You will use `X_train` to fit a Gaussian distribution
#     - You will use `X_val` and `y_val` as a cross validation set to select a threshold and determine anomalous vs normal examples

# %%
# Load the dataset
X_train, X_val, y_val = load_data()

# %% [markdown]
# #### View the variables
# Let's get more familiar with your dataset.
# - A good place to start is to just print out each variable and see what it contains.
#
# The code below prints the first five elements of each of the variables

# %%
# Display the first five elements of X_train
print("The first 5 elements of X_train are:\n", X_train[:5])
# Out:
# The first 5 elements of X_train are:
#  [[13.04681517 14.74115241]
#  [13.40852019 13.7632696 ]
#  [14.19591481 15.85318113]
#  [14.91470077 16.17425987]
#  [13.57669961 14.04284944]]

# %%
# Display the first five elements of X_val
print("The first 5 elements of X_val are\n", X_val[:5])
# Out:
# The first 5 elements of X_val are
#  [[15.79025979 14.9210243 ]
#  [13.63961877 15.32995521]
#  [14.86589943 16.47386514]
#  [13.58467605 13.98930611]
#  [13.46404167 15.63533011]]

# %%
# Display the first five elements of y_val
print("The first 5 elements of y_val are\n", y_val[:5])
# Out:
# The first 5 elements of y_val are
#  [0 0 0 0 0]

# %% [markdown]
# #### Check the dimensions of your variables
#
# Another useful way to get familiar with your data is to view its dimensions.
#
# The code below prints the shape of `X_train`, `X_val` and `y_val`.

# %%
print ('The shape of X_train is:', X_train.shape)
print ('The shape of X_val is:', X_val.shape)
print ('The shape of y_val is: ', y_val.shape)
# Out:
# The shape of X_train is: (307, 2)
# The shape of X_val is: (307, 2)
# The shape of y_val is:  (307,)

# %% [markdown]
# #### Visualize your data
#
# Before starting on any task, it is often useful to understand the data by visualizing it.
# - For this dataset, you can use a scatter plot to visualize the data (`X_train`), since it has only two properties to plot (throughput and latency)
#
# - Your plot should look similar to the one below
# <img src="images/figure1.png" width="500" height="500">

# %%
# Create a scatter plot of the data. To change the markers to blue "x",
# we used the 'marker' and 'c' parameters
plt.scatter(X_train[:, 0], X_train[:, 1], marker='x', c='b') 

# Set the title
plt.title("The first dataset")
# Set the y-axis label
plt.ylabel('Throughput (mb/s)')
# Set the x-axis label
plt.xlabel('Latency (ms)')
# Set axis range
plt.axis([0, 30, 0, 30])
plt.show()

# %% [markdown]
# <a name="2.3"></a>
# ### 2.3 Gaussian distribution
#
# To perform anomaly detection, you will first need to fit a model to the data’s distribution.
#
# * Given a training set $\{x^{(1)}, ..., x^{(m)}\}$ you want to estimate the Gaussian distribution for each
# of the features $x_i$.
#
# * Recall that the Gaussian distribution is given by
#
#    $$ p(x ; \mu,\sigma ^2) = \frac{1}{\sqrt{2 \pi \sigma ^2}}\exp^{ - \frac{(x - \mu)^2}{2 \sigma ^2} }$$
#
#    where $\mu$ is the mean and $\sigma^2$ is the variance.
#
# * For each feature $i = 1\ldots n$, you need to find parameters $\mu_i$ and $\sigma_i^2$ that fit the data in the $i$-th dimension $\{x_i^{(1)}, ..., x_i^{(m)}\}$ (the $i$-th dimension of each example).
#
# ### 2.3.1 Estimating parameters for a Gaussian distribution
#
# **Implementation**:
#
# Your task is to complete the code in `estimate_gaussian` below.

# %% [markdown]
# <a name="ex01"></a>
# ### Exercise 1
#
# Please complete the `estimate_gaussian` function below to calculate `mu` (mean for each feature in `X`) and `var` (variance for each feature in `X`).
#
# You can estimate the parameters, ($\mu_i$, $\sigma_i^2$), of the $i$-th
# feature by using the following equations. To estimate the mean, you will
# use:
#
# $$\mu_i = \frac{1}{m} \sum_{j=1}^m x_i^{(j)}$$
#
# and for the variance you will use:
# $$\sigma_i^2 = \frac{1}{m} \sum_{j=1}^m (x_i^{(j)} - \mu_i)^2$$
#
# If you get stuck, you can check out the hints presented after the cell below to help you with the implementation.

# %%
# UNQ_C1
# GRADED FUNCTION: estimate_gaussian

def estimate_gaussian(X): 
    """
    Calculates mean and variance of all features 
    in the dataset
    
    Args:
        X (ndarray): (m, n) Data matrix
    
    Returns:
        mu (ndarray): (n,) Mean of all features
        var (ndarray): (n,) Variance of all features
    """

    m, n = X.shape
    
    ### START CODE HERE ### 
    # initialize mu and var
    mu = np.zeros(m)
    var = np.zeros(m)

    mu = (1/m) * np.sum(X, axis=0)
    var = (1/m) * np.sum((X - mu) ** 2, axis = 0)
    
    ### END CODE HERE ### 
        
    return mu, var

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>Click for hints</b></font></summary>
#
#    * You can implement this function in two ways:
#       * 1 - by having two nested for loops - one looping over the **columns** of `X` (each feature) and then looping over each data point.
#       * 2 - in a vectorized manner by using `np.sum()` with `axis = 0` parameter (since we want the sum for each column)
#
#
#    * Here's how you can structure the overall implementation of this function for the vectorized implementation:
#      ```python
#     def estimate_gaussian(X):
#         m, n = X.shape
#
#         ### START CODE HERE ###
#         mu = # Your code here to calculate the mean of every feature
#         var = # Your code here to calculate the variance of every feature
#         ### END CODE HERE ###
#
#         return mu, var
#     ```
#
#     If you're still stuck, you can check the hints presented below to figure out how to calculate `mu` and `var`.
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate mu</b></font></summary>
#            &emsp; &emsp; You can use <a href="https://numpy.org/doc/stable/reference/generated/numpy.sum.html">np.sum</a> to with `axis = 0` parameter to get the sum for each column of an array
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate mu</b></font></summary>
#                &emsp; &emsp; You can compute mu as <code>mu = 1 / m * np.sum(X, axis = 0)</code>
#            </details>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate var</b></font></summary>
#            &emsp; &emsp; You can use <a href="https://numpy.org/doc/stable/reference/generated/numpy.sum.html">np.sum</a> to with `axis = 0` parameter to get the sum for each column of an array and <code>**2</code> to get the square.
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate var</b></font></summary>
#                &emsp; &emsp; You can compute var as <code> var = 1 / m * np.sum((X - mu) ** 2, axis = 0)</code>
#            </details>
#     </details>
#
# </details>

# %% [markdown]
# You can check if your implementation is correct by running the following test code:

# %%
# Estimate mean and variance of each feature
mu, var = estimate_gaussian(X_train)              

print("Mean of each feature:", mu)
print("Variance of each feature:", var)
    
# UNIT TEST
from public_tests import *
estimate_gaussian_test(estimate_gaussian)
# Out:
# Mean of each feature: [14.11222578 14.99771051]
# Variance of each feature: [1.83263141 1.70974533]
# All tests passed!

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Mean of each feature: <b>  </td>
#     <td> [14.11222578 14.99771051]</td>
#    </tr>
#    <tr>
#     <td> <b>Variance of each feature: <b>  </td>
#      <td> [1.83263141 1.70974533] </td>
#   </tr>
# </table>

# %% [markdown]
# Now that you have completed the code in `estimate_gaussian`, we will visualize the contours of the fitted Gaussian distribution.
#
# You should get a plot similar to the figure below.
# <img src="images/figure2.png" width="500" height="500">
#
#
# From your plot you can see that most of the examples are in the region with the highest probability, while the anomalous examples are in the regions with lower probabilities.

# %%
# Returns the density of the multivariate normal
# at each data point (row) of X_train
p = multivariate_gaussian(X_train, mu, var)

#Plotting code 
visualize_fit(X_train, mu, var)

# %% [markdown]
# ### 2.3.2 Selecting the threshold $\epsilon$
#
# Now that you have estimated the Gaussian parameters, you can investigate which examples have a very high probability given this distribution and which examples have a very low probability.
#
# * The low probability examples are more likely to be the anomalies in our dataset.
# * One way to determine which examples are anomalies is to select a threshold based on a cross validation set.
#
# In this section, you will complete the code in `select_threshold` to select the threshold $\varepsilon$ using the $F_1$ score on a cross validation set.
#
# * For this, we will use a cross validation set
# $\{(x_{\rm cv}^{(1)}, y_{\rm cv}^{(1)}),\ldots, (x_{\rm cv}^{(m_{\rm cv})}, y_{\rm cv}^{(m_{\rm cv})})\}$, where the label $y=1$ corresponds to an anomalous example, and $y=0$ corresponds to a normal example.
# * For each cross validation example, we will compute $p(x_{\rm cv}^{(i)})$. The vector of all of these probabilities $p(x_{\rm cv}^{(1)}), \ldots, p(x_{\rm cv}^{(m_{\rm cv})})$ is passed to `select_threshold` in the vector `p_val`.
# * The corresponding labels $y_{\rm cv}^{(1)}, \ldots, y_{\rm cv}^{(m_{\rm cv})}$ are passed to the same function in the vector `y_val`.

# %% [markdown]
# <a name="ex02"></a>
# ### Exercise 2
# Please complete the `select_threshold` function below to find the best threshold to use for selecting outliers based on the results from the validation set (`p_val`) and the ground truth (`y_val`).
#
# * In the provided code `select_threshold`, there is already a loop that will try many different values of $\varepsilon$ and select the best $\varepsilon$ based on the $F_1$ score.
#
# * You need to implement code to calculate the F1 score from choosing `epsilon` as the threshold and place the value in `F1`.
#
#   * Recall that if an example $x$ has a low probability $p(x) < \varepsilon$, then it is classified as an anomaly.
#
#   * Then, you can compute precision and recall by:
#    $$\begin{aligned}
#    prec&=&\frac{tp}{tp+fp}\\
#    rec&=&\frac{tp}{tp+fn},
#    \end{aligned}$$ where
#     * $tp$ is the number of true positives: the ground truth label says it’s an anomaly and our algorithm correctly classified it as an anomaly.
#     * $fp$ is the number of false positives: the ground truth label says it’s not an anomaly, but our algorithm incorrectly classified it as an anomaly.
#     * $fn$ is the number of false negatives: the ground truth label says it’s an anomaly, but our algorithm incorrectly classified it as not being anomalous.
#
#   * The $F_1$ score is computed using precision ($prec$) and recall ($rec$) as follows:
#     $$F_1 = \frac{2\cdot prec \cdot rec}{prec + rec}$$
#
# **Implementation Note:**
# In order to compute $tp$, $fp$ and $fn$, you may be able to use a vectorized implementation rather than loop over all the examples.
#
#
# If you get stuck, you can check out the hints presented after the cell below to help you with the implementation.

# %%
# UNQ_C2
# GRADED FUNCTION: select_threshold

def select_threshold(y_val, p_val): 
    """
    Finds the best threshold to use for selecting outliers 
    based on the results from a validation set (p_val) 
    and the ground truth (y_val)
    
    Args:
        y_val (ndarray): Ground truth on validation set
        p_val (ndarray): Results on validation set
        
    Returns:
        epsilon (float): Threshold chosen 
        F1 (float):      F1 score by choosing epsilon as threshold
    """ 

    best_epsilon = 0
    best_F1 = 0
    F1 = 0
    
    step_size = (max(p_val) - min(p_val)) / 1000
    
    for epsilon in np.arange(min(p_val), max(p_val), step_size):
    
        ### START CODE HERE ### 
        
        predictions = p_val<epsilon
        
        tp = np.sum((predictions == 1) & (y_val == 1)) # Your code here to calculate number of true positives
        fp = np.sum((predictions == 1) & (y_val == 0) ) # Your code here to calculate number of false positives
        fn = np.sum((predictions == 0) & (y_val == 1) ) # Your code here to calculate number of false negatives

        prec = tp / (tp+fp) # Your code here to calculate precision
        rec = tp / (tp+fn) # Your code here to calculate recall

        F1 = (2*prec*rec) / (prec+rec) # Your code here to calculate F1
        print(f'predcitions: {predictions[:5]} ')
        print(f'tp:{tp}, fp:{fp}, fn:{fn} ')
        print(f'prec: {prec}, rec:{rec}')
        print(f'F1:{F1} epsilon: {epsilon} ')
        
        
        ### END CODE HERE ### 
        
        if F1 > best_F1:
            best_F1 = F1
            best_epsilon = epsilon
        
    return best_epsilon, best_F1

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>Click for hints</b></font></summary>
#
#    * Here's how you can structure the overall implementation of this function for the vectorized implementation:
#      ```python
#     def select_threshold(y_val, p_val):
#         best_epsilon = 0
#         best_F1 = 0
#         F1 = 0
#
#         step_size = (max(p_val) - min(p_val)) / 1000
#
#         for epsilon in np.arange(min(p_val), max(p_val), step_size):
#
#             ### START CODE HERE ###
#             predictions = # Your code here to calculate predictions for each example using epsilon as threshold
#
#             tp = # Your code here to calculate number of true positives
#             fp = # Your code here to calculate number of false positives
#             fn = # Your code here to calculate number of false negatives
#
#             prec = # Your code here to calculate precision
#             rec = # Your code here to calculate recall
#
#             F1 = # Your code here to calculate F1
#             ### END CODE HERE ###
#
#             if F1 > best_F1:
#                 best_F1 = F1
#                 best_epsilon = epsilon
#
#         return best_epsilon, best_F1
#     ```
#
#     If you're still stuck, you can check the hints presented below to figure out how to calculate each variable.
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate predictions</b></font></summary>
#            &emsp; &emsp; If an example  𝑥  has a low probability  $p(x) < \epsilon$ , then it is classified as an anomaly. To get predictions for each example (0/ False for normal and 1/True for anomaly), you can use <code>predictions = (p_val < epsilon)</code>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate tp, fp, fn</b></font></summary>
#            &emsp; &emsp;
#         <ul>
#           <li>If you have several binary values in an $n$-dimensional
# binary vector, you can find out how many values in this vector are 0 by using:  `np.sum(v == 0)`</li>
#           <li>You can also apply a logical *and* operator to such binary vectors. For instance,  `predictions` is a binary vector of the size of your number of cross validation set, where the $i$-th element is 1 if your algorithm considers $x_{\rm cv}^{(i)}$ an anomaly, and 0 otherwise. </li>
#           <li>You can then, for example, compute the number of false positives using:
# <code>fp = sum((predictions == 1) & (y_val == 0))</code>.</li>
#         </ul>
#          <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; More hints to calculate tp, fn</b></font></summary>
#                &emsp; &emsp;
#              <ul>
#               <li>You can compute tp as <code> tp = np.sum((predictions == 1) & (y_val == 1))</code></li>
#               <li>You can compute tn as <code> fn = np.sum((predictions == 0) & (y_val == 1))</code></li>
#               </ul>
#           </details>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate precision</b></font></summary>
#            &emsp; &emsp; You can calculate precision as <code>prec = tp / (tp + fp)</code>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate recall</b></font></summary>
#            &emsp; &emsp; You can calculate recall as <code>rec = tp / (tp + fn)</code>
#     </details>
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>Hint to calculate F1</b></font></summary>
#            &emsp; &emsp; You can calculate F1 as <code>F1 = 2 * prec * rec / (prec + rec)</code>
#     </details>
#
# </details>

# %% [markdown]
# You can check your implementation using the code below

# %%
p_val = multivariate_gaussian(X_val, mu, var)
epsilon, F1 = select_threshold(y_val, p_val)

print('Best epsilon found using cross-validation: %e' % epsilon)
print('Best F1 on Cross Validation Set: %f' % F1)
    
# UNIT TEST
select_threshold_test(select_threshold)
# Out:
# predcitions: [False False False False False]
# tp:0, fp:0, fn:9
# prec: nan, rec:0.0
# F1:nan epsilon: 4.513250930309714e-36
# predcitions: [False False False False False]
# tp:7, fp:0, fn:2
# prec: 1.0, rec:0.7777777777777778
# F1:0.8750000000000001 epsilon: 8.990852779269493e-05
# predcitions: [False False False False False]
# tp:7, fp:0, fn:2
# prec: 1.0, rec:0.7777777777777778
# F1:0.8750000000000001 epsilon: 0.00017981705558538986
# predcitions: [False False False False False]
# tp:7, fp:0, fn:2
# prec: 1.0, rec:0.7777777777777778
# F1:0.8750000000000001 epsilon: 0.0002697255833780848
# predcitions: [False False False False False]
# tp:7, fp:0, fn:2
# prec: 1.0, rec:0.7777777777777778
# F1:0.8750000000000001 epsilon: 0.00035963411117077973
# predcitions: [False False False False False]
# tp:7, fp:0, fn:2
# prec: 1.0, rec:0.7777777777777778
# F1:0.8750000000000001 epsilon: 0.0004495426389634747
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0005394511667561696
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0006293596945488645
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0007192682223415595
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0008091767501342544
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0008990852779269493
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0009889938057196443
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0010789023335123391
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0011688108613050342
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.001258719389097729
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.001348627916890424
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.001438536444683119
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0015284449724758137
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0016183535002685088
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0017082620280612036
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0017981705558538987
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0018880790836465935
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0019779876114392886
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0020678961392319836
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0021578046670246783
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0022477131948173733
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0023376217226100684
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002427530250402763
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002517438778195458
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002607347305988153
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002697255833780848
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0027871643615735428
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002877072889366238
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.002966981417158933
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0030568899449516275
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0031467984727443226
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0032367070005370176
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0033266155283297127
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0034165240561224073
# predcitions: [False False False False False]
# tp:7, fp:1, fn:2
# prec: 0.875, rec:0.7777777777777778
# F1:0.823529411764706 epsilon: 0.0035064325839151023
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0035963411117077974
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.003686249639500492
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.003776158167293187
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.003866066695085882
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.003955975222878577
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004045883750671272
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004135792278463967
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004225700806256662
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0043156093340493565
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004405517861842052
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004495426389634747
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004585334917427441
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004675243445220137
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004765151973012831
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.004855060500805526
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0049449690285982215
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005034877556390916
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005124786084183611
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005214694611976306
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005304603139769001
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005394511667561696
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005484420195354391
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0055743287231470855
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005664237250939781
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005754145778732476
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00584405430652517
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.005933962834317866
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00602387136211056
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.006113779889903255
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0062036884176959505
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.006293596945488645
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.006383505473281341
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.006473414001074035
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00656332252886673
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.006653231056659425
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00674313958445212
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0068330481122448146
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00692295664003751
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007012865167830205
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007102773695622899
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007192682223415595
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007282590751208289
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007372499279000984
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.0074624078067936795
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007552316334586374
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.00764222486237907
# predcitions: [False False False False False]
# tp:7, fp:2, fn:2
# prec: 0.7777777777777778, rec:0.7777777777777778
# F1:0.7777777777777778 epsilon: 0.007732133390171764
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.00782204191796446
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.007911950445757154
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.008001858973549849
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.008091767501342544
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.008181676029135238
# predcitions: [False False False False False]
# tp:7, fp:3, fn:2
# prec: 0.7, rec:0.7777777777777778
# F1:0.7368421052631577 epsilon: 0.008271584556927935
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.00836149308472063
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008451401612513324
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008541310140306018
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008631218668098713
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008721127195891408
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008811035723684104
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008900944251476799
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.008990852779269493
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009080761307062188
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009170669834854882
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009260578362647579
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009350486890440273
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009440395418232968
# predcitions: [False False False False False]
# tp:7, fp:4, fn:2
# prec: 0.6363636363636364, rec:0.7777777777777778
# F1:0.7000000000000001 epsilon: 0.009530303946025663
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.009620212473818357
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.009710121001611052
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.009800029529403748
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.009889938057196443
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.009979846584989138
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010069755112781832
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010159663640574527
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010249572168367221
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010339480696159918
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010429389223952612
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010519297751745307
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010609206279538002
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010699114807330696
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010789023335123393
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010878931862916087
# predcitions: [False False False False False]
# tp:7, fp:5, fn:2
# prec: 0.5833333333333334, rec:0.7777777777777778
# F1:0.6666666666666666 epsilon: 0.010968840390708782
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011058748918501476
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011148657446294171
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011238565974086866
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011328474501879562
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011418383029672257
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011508291557464951
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011598200085257646
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.01168810861305034
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011778017140843037
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011867925668635732
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.011957834196428426
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.01204774272422112
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.012137651252013815
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.01222755977980651
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.012317468307599206
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.012407376835391901
# predcitions: [False False False False False]
# tp:7, fp:6, fn:2
# prec: 0.5384615384615384, rec:0.7777777777777778
# F1:0.6363636363636364 epsilon: 0.012497285363184596
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.01258719389097729
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.012677102418769985
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.012767010946562681
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.012856919474355376
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.01294682800214807
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.013036736529940765
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.01312664505773346
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.013216553585526154
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.01330646211331885
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.013396370641111545
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.01348627916890424
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.013576187696696934
# predcitions: [False False False False False]
# tp:7, fp:7, fn:2
# prec: 0.5, rec:0.7777777777777778
# F1:0.6086956521739131 epsilon: 0.013666096224489629
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.013756004752282324
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.01384591328007502
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.013935821807867715
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.01402573033566041
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.014115638863453104
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.014205547391245799
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.014295455919038495
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.01438536444683119
# predcitions: [False False False False False]
# tp:7, fp:8, fn:2
# prec: 0.4666666666666667, rec:0.7777777777777778
# F1:0.5833333333333334 epsilon: 0.014475272974623884
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.014565181502416579
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.014655090030209273
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.014744998558001968
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.014834907085794664
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.014924815613587359
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.015014724141380054
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.015104632669172748
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.015194541196965443
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.01528444972475814
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.015374358252550834
# predcitions: [False False False False False]
# tp:7, fp:9, fn:2
# prec: 0.4375, rec:0.7777777777777778
# F1:0.56 epsilon: 0.015464266780343528
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.015554175308136223
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01564408383592892
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.015733992363721614
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01582390089151431
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.015913809419307003
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016003717947099698
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016093626474892393
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016183535002685087
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016273443530477782
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016363352058270476
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01645326058606317
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01654316911385587
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016633077641648564
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01672298616944126
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016812894697233953
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016902803225026648
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.016992711752819342
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017082620280612037
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01717252880840473
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017262437336197426
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01735234586399012
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017442254391782815
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017532162919575513
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017622071447368208
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017711979975160903
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017801888502953597
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017891797030746292
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.017981705558538987
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01807161408633168
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018161522614124376
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01825143114191707
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018341339669709765
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01843124819750246
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018521156725295158
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018611065253087852
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018700973780880547
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01879088230867324
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.018880790836465936
# predcitions: [False False False False False]
# tp:7, fp:10, fn:2
# prec: 0.4117647058823529, rec:0.7777777777777778
# F1:0.5384615384615384 epsilon: 0.01897069936425863
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.019060607892051325
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.01915051641984402
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.019240424947636715
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.01933033347542941
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.019420242003222104
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.0195101505310148
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.019600059058807497
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.01968996758660019
# predcitions: [False False False False False]
# tp:7, fp:11, fn:2
# prec: 0.3888888888888889, rec:0.7777777777777778
# F1:0.5185185185185185 epsilon: 0.019779876114392886
# predcitions: [False False False False False]
# tp:7, fp:12, fn:2
# prec: 0.3684210526315789, rec:0.7777777777777778
# F1:0.5 epsilon: 0.01986978464218558
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.019959693169978275
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.02004960169777097
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020139510225563664
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.02022941875335636
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020319327281149054
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020409235808941748
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020499144336734443
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.02058905286452714
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020678961392319836
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.02076886992011253
# predcitions: [False False False False False]
# tp:7, fp:13, fn:2
# prec: 0.35, rec:0.7777777777777778
# F1:0.48275862068965514 epsilon: 0.020858778447905225
# predcitions: [False False False False False]
# tp:7, fp:14, fn:2
# prec: 0.3333333333333333, rec:0.7777777777777778
# F1:0.4666666666666666 epsilon: 0.02094868697569792
# predcitions: [False False False False False]
# tp:7, fp:14, fn:2
# prec: 0.3333333333333333, rec:0.7777777777777778
# F1:0.4666666666666666 epsilon: 0.021038595503490614
# predcitions: [False False False False False]
# tp:7, fp:15, fn:2
# prec: 0.3181818181818182, rec:0.7777777777777778
# F1:0.45161290322580644 epsilon: 0.02112850403128331
# predcitions: [False False False False False]
# tp:7, fp:15, fn:2
# prec: 0.3181818181818182, rec:0.7777777777777778
# F1:0.45161290322580644 epsilon: 0.021218412559076003
# predcitions: [False False False False False]
# tp:7, fp:15, fn:2
# prec: 0.3181818181818182, rec:0.7777777777777778
# F1:0.45161290322580644 epsilon: 0.021308321086868698
# predcitions: [False False False False False]
# tp:7, fp:15, fn:2
# prec: 0.3181818181818182, rec:0.7777777777777778
# F1:0.45161290322580644 epsilon: 0.021398229614661392
# predcitions: [False False False False False]
# tp:7, fp:16, fn:2
# prec: 0.30434782608695654, rec:0.7777777777777778
# F1:0.43750000000000006 epsilon: 0.021488138142454087
# predcitions: [False False False False False]
# tp:7, fp:16, fn:2
# prec: 0.30434782608695654, rec:0.7777777777777778
# F1:0.43750000000000006 epsilon: 0.021578046670246785
# predcitions: [False False False False False]
# tp:7, fp:16, fn:2
# prec: 0.30434782608695654, rec:0.7777777777777778
# F1:0.43750000000000006 epsilon: 0.02166795519803948
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.021757863725832174
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.02184777225362487
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.021937680781417564
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.02202758930921026
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022117497837002953
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022207406364795648
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022297314892588342
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022387223420381037
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.02247713194817373
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.02256704047596643
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022656949003759124
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.02274685753155182
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022836766059344513
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.022926674587137208
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.023016583114929903
# predcitions: [False False False False False]
# tp:7, fp:17, fn:2
# prec: 0.2916666666666667, rec:0.7777777777777778
# F1:0.42424242424242425 epsilon: 0.023106491642722597
# predcitions: [False False False False False]
# tp:7, fp:18, fn:2
# prec: 0.28, rec:0.7777777777777778
# F1:0.4117647058823529 epsilon: 0.023196400170515292
# predcitions: [False False False False False]
# tp:7, fp:18, fn:2
# prec: 0.28, rec:0.7777777777777778
# F1:0.4117647058823529 epsilon: 0.023286308698307986
# predcitions: [False False False False False]
# tp:7, fp:18, fn:2
# prec: 0.28, rec:0.7777777777777778
# F1:0.4117647058823529 epsilon: 0.02337621722610068
# predcitions: [False False False False False]
# tp:7, fp:18, fn:2
# prec: 0.28, rec:0.7777777777777778
# F1:0.4117647058823529 epsilon: 0.023466125753893376
# predcitions: [False False False False False]
# tp:7, fp:18, fn:2
# prec: 0.28, rec:0.7777777777777778
# F1:0.4117647058823529 epsilon: 0.023556034281686074
# predcitions: [False False False False False]
# tp:7, fp:19, fn:2
# prec: 0.2692307692307692, rec:0.7777777777777778
# F1:0.39999999999999997 epsilon: 0.02364594280947877
# predcitions: [False False False False False]
# tp:7, fp:19, fn:2
# prec: 0.2692307692307692, rec:0.7777777777777778
# F1:0.39999999999999997 epsilon: 0.023735851337271463
# predcitions: [False False False False False]
# tp:7, fp:19, fn:2
# prec: 0.2692307692307692, rec:0.7777777777777778
# F1:0.39999999999999997 epsilon: 0.023825759865064158
# predcitions: [False False False False False]
# tp:7, fp:19, fn:2
# prec: 0.2692307692307692, rec:0.7777777777777778
# F1:0.39999999999999997 epsilon: 0.023915668392856852
# predcitions: [False False False False False]
# tp:7, fp:19, fn:2
# prec: 0.2692307692307692, rec:0.7777777777777778
# F1:0.39999999999999997 epsilon: 0.024005576920649547
# predcitions: [False False False False False]
# tp:7, fp:20, fn:2
# prec: 0.25925925925925924, rec:0.7777777777777778
# F1:0.3888888888888889 epsilon: 0.02409548544844224
# predcitions: [False False False False False]
# tp:7, fp:20, fn:2
# prec: 0.25925925925925924, rec:0.7777777777777778
# F1:0.3888888888888889 epsilon: 0.024185393976234936
# predcitions: [False False False False False]
# tp:7, fp:22, fn:2
# prec: 0.2413793103448276, rec:0.7777777777777778
# F1:0.368421052631579 epsilon: 0.02427530250402763
# predcitions: [False False False False False]
# tp:7, fp:22, fn:2
# prec: 0.2413793103448276, rec:0.7777777777777778
# F1:0.368421052631579 epsilon: 0.024365211031820325
# predcitions: [False False False False False]
# tp:7, fp:22, fn:2
# prec: 0.2413793103448276, rec:0.7777777777777778
# F1:0.368421052631579 epsilon: 0.02445511955961302
# predcitions: [False False False False False]
# tp:7, fp:22, fn:2
# prec: 0.2413793103448276, rec:0.7777777777777778
# F1:0.368421052631579 epsilon: 0.024545028087405718
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.024634936615198413
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.024724845142991107
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.024814753670783802
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.024904662198576497
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.02499457072636919
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.025084479254161886
# predcitions: [False False False False False]
# tp:7, fp:23, fn:2
# prec: 0.23333333333333334, rec:0.7777777777777778
# F1:0.35897435897435903 epsilon: 0.02517438778195458
# predcitions: [False False False False False]
# tp:7, fp:24, fn:2
# prec: 0.22580645161290322, rec:0.7777777777777778
# F1:0.35000000000000003 epsilon: 0.025264296309747275
# predcitions: [False False False False False]
# tp:7, fp:24, fn:2
# prec: 0.22580645161290322, rec:0.7777777777777778
# F1:0.35000000000000003 epsilon: 0.02535420483753997
# predcitions: [False False False False False]
# tp:7, fp:24, fn:2
# prec: 0.22580645161290322, rec:0.7777777777777778
# F1:0.35000000000000003 epsilon: 0.025444113365332664
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.025534021893125362
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.025623930420918057
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.02571383894871075
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.025803747476503446
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.02589365600429614
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.025983564532088835
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.02607347305988153
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.026163381587674225
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.02625329011546692
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.026343198643259614
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.02643310717105231
# predcitions: [False False False False False]
# tp:7, fp:25, fn:2
# prec: 0.21875, rec:0.7777777777777778
# F1:0.34146341463414637 epsilon: 0.026523015698845007
# predcitions: [False False False False False]
# tp:7, fp:26, fn:2
# prec: 0.21212121212121213, rec:0.7777777777777778
# F1:0.3333333333333333 epsilon: 0.0266129242266377
# predcitions: [False False False False False]
# ...
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043659
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043708000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043757000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043806000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043855000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043904000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:37, fn:0
# prec: 0.1590909090909091, rec:1.0
# F1:0.2745098039215686 epsilon: 0.043953000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044002000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04405100000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04410000000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04414900000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04419800000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044247
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044296
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044345
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044394
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044443
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044492000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044541000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044590000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044639000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044688000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044737000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.044786000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04483500000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04488400000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04493300000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:38, fn:0
# prec: 0.15555555555555556, rec:1.0
# F1:0.2692307692307693 epsilon: 0.04498200000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045031
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.04508
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045129
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045178
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045227
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045276000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045325000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045374000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045423000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045472000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045521000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045570000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.04561900000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.04566800000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.04571700000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.04576600000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045815
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045864
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045913
# predcitions: [ True  True  True  True  True]
# tp:7, fp:39, fn:0
# prec: 0.15217391304347827, rec:1.0
# F1:0.2641509433962264 epsilon: 0.045962
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046011
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046060000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046109000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046158000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046207000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046256000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046305000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046354000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.04640300000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.04645200000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.04650100000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.04655000000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046599
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046648
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046697
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046746
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046795
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046844000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046893000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046942000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:40, fn:0
# prec: 0.14893617021276595, rec:1.0
# F1:0.25925925925925924 epsilon: 0.046991000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047040000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047089000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047138000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04718700000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04723600000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04728500000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04733400000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04738300000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047432
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047481
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04753
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047579
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047628000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047677000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047726000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047775000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047824000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047873000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.047922000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:41, fn:0
# prec: 0.14583333333333334, rec:1.0
# F1:0.2545454545454546 epsilon: 0.04797100000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04802000000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04806900000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04811800000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04816700000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048216
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048265
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048314
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048363
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048412000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048461000000000004
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048510000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048559000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048608000000000005
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048657000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.048706000000000006
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04875500000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04880400000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04885300000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04890200000000001
# predcitions: [ True  True  True  True  True]
# tp:7, fp:42, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 0.04895100000000001
# All tests passed!

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Best epsilon found using cross-validation: <b>  </td>
#     <td> 8.99e-05</td>
#    </tr>
#    <tr>
#     <td> <b>Best F1 on Cross Validation Set: <b>  </td>
#      <td> 0.875 </td>
#   </tr>
# </table>

# %% [markdown]
# Now we will run your anomaly detection code and circle the anomalies in the plot (Figure 3 below).
#
# <img src="images/figure3.png" width="500" height="500">

# %%
# Find the outliers in the training set 
outliers = p < epsilon

# Visualize the fit
visualize_fit(X_train, mu, var)

# Draw a red circle around those outliers
plt.plot(X_train[outliers, 0], X_train[outliers, 1], 'ro',
         markersize= 10,markerfacecolor='none', markeredgewidth=2)

# %% [markdown]
# <a name="2.4"></a>
# ### 2.4 High dimensional dataset
#
# Now,  we will run the anomaly detection algorithm that you implemented on a more realistic and much harder dataset.
#
# In this dataset, each example is described by 11 features, capturing many more properties of your compute servers.
#
# Let's start by loading the dataset.
#
# - The `load_data()` function shown below loads the data into variables `X_train_high`, `X_val_high` and `y_val_high`
#     -  `_high` is meant to distinguish these variables from the ones used in the previous part
#     - We will use `X_train_high` to fit Gaussian distribution
#     - We will use `X_val_high` and `y_val_high` as a cross validation set to select a threshold and determine anomalous vs normal examples

# %%
# load the dataset
X_train_high, X_val_high, y_val_high = load_data_multi()

# %% [markdown]
# #### Check the dimensions of your variables
#
# Let's check the dimensions of these new variables to become familiar with the data

# %%
print ('The shape of X_train_high is:', X_train_high.shape)
print ('The shape of X_val_high is:', X_val_high.shape)
print ('The shape of y_val_high is: ', y_val_high.shape)
# Out:
# The shape of X_train_high is: (1000, 11)
# The shape of X_val_high is: (100, 11)
# The shape of y_val_high is:  (100,)

# %% [markdown]
# #### Anomaly detection
#
# Now, let's run the anomaly detection algorithm on this new dataset.
#
# The code below will use your code to
# * Estimate the Gaussian parameters ($\mu_i$ and $\sigma_i^2$)
# * Evaluate the probabilities for both the training data `X_train_high` from which you estimated the Gaussian parameters, as well as for the the cross-validation set `X_val_high`.
# * Finally, it will use `select_threshold` to find the best threshold $\varepsilon$.

# %%
# Apply the same steps to the larger dataset

# Estimate the Gaussian parameters
mu_high, var_high = estimate_gaussian(X_train_high)

# Evaluate the probabilites for the training set
p_high = multivariate_gaussian(X_train_high, mu_high, var_high)

# Evaluate the probabilites for the cross validation set
p_val_high = multivariate_gaussian(X_val_high, mu_high, var_high)

# Find the best threshold
epsilon_high, F1_high = select_threshold(y_val_high, p_val_high)

print('Best epsilon found using cross-validation: %e'% epsilon_high)
print('Best F1 on Cross Validation Set:  %f'% F1_high)
print('# Anomalies found: %d'% sum(p_high < epsilon_high))
# Out:
# predcitions: [False False False False False]
# tp:0, fp:0, fn:10
# prec: nan, rec:0.0
# F1:nan epsilon: 5.953349076111392e-26
# predcitions: [ True False False  True False]
# tp:8, fp:8, fn:2
# prec: 0.5, rec:0.8
# F1:0.6153846153846154 epsilon: 1.3772288907613575e-18
# predcitions: [ True False False  True False]
# tp:9, fp:13, fn:1
# prec: 0.4090909090909091, rec:0.9
# F1:0.5625000000000001 epsilon: 2.7544577219892245e-18
# predcitions: [ True False False  True False]
# tp:9, fp:14, fn:1
# prec: 0.391304347826087, rec:0.9
# F1:0.5454545454545454 epsilon: 4.131686553217091e-18
# predcitions: [ True False False  True False]
# tp:9, fp:17, fn:1
# prec: 0.34615384615384615, rec:0.9
# F1:0.5 epsilon: 5.508915384444958e-18
# predcitions: [ True False False  True False]
# tp:9, fp:19, fn:1
# prec: 0.32142857142857145, rec:0.9
# F1:0.4736842105263158 epsilon: 6.886144215672824e-18
# predcitions: [ True False False  True False]
# tp:9, fp:20, fn:1
# prec: 0.3103448275862069, rec:0.9
# F1:0.4615384615384615 epsilon: 8.263373046900692e-18
# predcitions: [ True False False  True False]
# tp:9, fp:22, fn:1
# prec: 0.2903225806451613, rec:0.9
# F1:0.4390243902439024 epsilon: 9.640601878128558e-18
# predcitions: [ True False False  True False]
# tp:9, fp:22, fn:1
# prec: 0.2903225806451613, rec:0.9
# F1:0.4390243902439024 epsilon: 1.1017830709356426e-17
# predcitions: [ True False False  True False]
# tp:9, fp:23, fn:1
# prec: 0.28125, rec:0.9
# F1:0.4285714285714286 epsilon: 1.2395059540584293e-17
# predcitions: [ True False False  True False]
# tp:9, fp:24, fn:1
# prec: 0.2727272727272727, rec:0.9
# F1:0.41860465116279066 epsilon: 1.3772288371812159e-17
# predcitions: [ True False False  True False]
# tp:9, fp:27, fn:1
# prec: 0.25, rec:0.9
# F1:0.391304347826087 epsilon: 1.5149517203040025e-17
# predcitions: [ True False False  True False]
# tp:10, fp:27, fn:0
# prec: 0.2702702702702703, rec:1.0
# F1:0.4255319148936171 epsilon: 1.6526746034267892e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:30, fn:0
# prec: 0.25, rec:1.0
# F1:0.4 epsilon: 1.790397486549576e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:30, fn:0
# prec: 0.25, rec:1.0
# F1:0.4 epsilon: 1.9281203696723624e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:31, fn:0
# prec: 0.24390243902439024, rec:1.0
# F1:0.39215686274509803 epsilon: 2.065843252795149e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:31, fn:0
# prec: 0.24390243902439024, rec:1.0
# F1:0.39215686274509803 epsilon: 2.2035661359179358e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:31, fn:0
# prec: 0.24390243902439024, rec:1.0
# F1:0.39215686274509803 epsilon: 2.3412890190407226e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:32, fn:0
# prec: 0.23809523809523808, rec:1.0
# F1:0.3846153846153846 epsilon: 2.4790119021635093e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:32, fn:0
# prec: 0.23809523809523808, rec:1.0
# F1:0.3846153846153846 epsilon: 2.6167347852862957e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:33, fn:0
# prec: 0.23255813953488372, rec:1.0
# F1:0.37735849056603776 epsilon: 2.7544576684090825e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:33, fn:0
# prec: 0.23255813953488372, rec:1.0
# F1:0.37735849056603776 epsilon: 2.8921805515318695e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:34, fn:0
# prec: 0.22727272727272727, rec:1.0
# F1:0.37037037037037035 epsilon: 3.029903434654656e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:35, fn:0
# prec: 0.2222222222222222, rec:1.0
# F1:0.3636363636363636 epsilon: 3.1676263177774424e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:36, fn:0
# prec: 0.21739130434782608, rec:1.0
# F1:0.3571428571428571 epsilon: 3.3053492009002294e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:36, fn:0
# prec: 0.21739130434782608, rec:1.0
# F1:0.3571428571428571 epsilon: 3.443072084023016e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:36, fn:0
# prec: 0.21739130434782608, rec:1.0
# F1:0.3571428571428571 epsilon: 3.580794967145803e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:37, fn:0
# prec: 0.2127659574468085, rec:1.0
# F1:0.3508771929824561 epsilon: 3.718517850268589e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:38, fn:0
# prec: 0.20833333333333334, rec:1.0
# F1:0.3448275862068966 epsilon: 3.856240733391376e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:38, fn:0
# prec: 0.20833333333333334, rec:1.0
# F1:0.3448275862068966 epsilon: 3.993963616514163e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:38, fn:0
# prec: 0.20833333333333334, rec:1.0
# F1:0.3448275862068966 epsilon: 4.131686499636949e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:38, fn:0
# prec: 0.20833333333333334, rec:1.0
# F1:0.3448275862068966 epsilon: 4.269409382759736e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:38, fn:0
# prec: 0.20833333333333334, rec:1.0
# F1:0.3448275862068966 epsilon: 4.4071322658825227e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:39, fn:0
# prec: 0.20408163265306123, rec:1.0
# F1:0.3389830508474576 epsilon: 4.544855149005309e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:39, fn:0
# prec: 0.20408163265306123, rec:1.0
# F1:0.3389830508474576 epsilon: 4.682578032128096e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:40, fn:0
# prec: 0.2, rec:1.0
# F1:0.33333333333333337 epsilon: 4.8203009152508826e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:41, fn:0
# prec: 0.19607843137254902, rec:1.0
# F1:0.3278688524590164 epsilon: 4.9580237983736696e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:41, fn:0
# prec: 0.19607843137254902, rec:1.0
# F1:0.3278688524590164 epsilon: 5.095746681496456e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:41, fn:0
# prec: 0.19607843137254902, rec:1.0
# F1:0.3278688524590164 epsilon: 5.2334695646192425e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:41, fn:0
# prec: 0.19607843137254902, rec:1.0
# F1:0.3278688524590164 epsilon: 5.3711924477420295e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:42, fn:0
# prec: 0.19230769230769232, rec:1.0
# F1:0.32258064516129037 epsilon: 5.508915330864816e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:44, fn:0
# prec: 0.18518518518518517, rec:1.0
# F1:0.3125 epsilon: 5.646638213987603e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:44, fn:0
# prec: 0.18518518518518517, rec:1.0
# F1:0.3125 epsilon: 5.784361097110391e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:44, fn:0
# prec: 0.18518518518518517, rec:1.0
# F1:0.3125 epsilon: 5.922083980233177e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:45, fn:0
# prec: 0.18181818181818182, rec:1.0
# F1:0.3076923076923077 epsilon: 6.059806863355964e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.19752974647875e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.335252629601536e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.472975512724324e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.61069839584711e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.748421278969897e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 6.886144162092683e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:46, fn:0
# prec: 0.17857142857142858, rec:1.0
# F1:0.30303030303030304 epsilon: 7.02386704521547e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.161589928338257e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.299312811461044e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.43703569458383e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.574758577706617e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.712481460829403e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.850204343952191e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 7.987927227074977e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 8.125650110197764e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 8.26337299332055e-17
# predcitions: [ True  True False  True False]
# tp:10, fp:47, fn:0
# prec: 0.17543859649122806, rec:1.0
# F1:0.29850746268656714 epsilon: 8.401095876443336e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 8.538818759566124e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 8.67654164268891e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 8.814264525811697e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 8.951987408934483e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.08971029205727e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.227433175180058e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.365156058302844e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.50287894142563e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.640601824548417e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.778324707671203e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:48, fn:0
# prec: 0.1724137931034483, rec:1.0
# F1:0.29411764705882354 epsilon: 9.916047590793991e-17
# predcitions: [ True  True  True  True False]
# tp:10, fp:49, fn:0
# prec: 0.1694915254237288, rec:1.0
# F1:0.2898550724637681 epsilon: 1.0053770473916777e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.0191493357039564e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.032921624016235e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.0466939123285137e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.0604662006407924e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.0742384889530711e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:50, fn:0
# prec: 0.16666666666666666, rec:1.0
# F1:0.2857142857142857 epsilon: 1.0880107772653497e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.1017830655776284e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.1155553538899069e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.1293276422021855e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.1430999305144642e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.156872218826743e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:51, fn:0
# prec: 0.16393442622950818, rec:1.0
# F1:0.28169014084507044 epsilon: 1.1706445071390217e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:52, fn:0
# prec: 0.16129032258064516, rec:1.0
# F1:0.27777777777777773 epsilon: 1.1844167954513003e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:53, fn:0
# prec: 0.15873015873015872, rec:1.0
# F1:0.27397260273972607 epsilon: 1.198189083763579e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.2119613720758576e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.2257336603881363e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.239505948700415e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.2532782370126935e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.2670505253249722e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:54, fn:0
# prec: 0.15625, rec:1.0
# F1:0.2702702702702703 epsilon: 1.2808228136372508e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:55, fn:0
# prec: 0.15384615384615385, rec:1.0
# F1:0.2666666666666667 epsilon: 1.2945951019495297e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:55, fn:0
# prec: 0.15384615384615385, rec:1.0
# F1:0.2666666666666667 epsilon: 1.3083673902618084e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:55, fn:0
# prec: 0.15384615384615385, rec:1.0
# F1:0.2666666666666667 epsilon: 1.322139678574087e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:55, fn:0
# prec: 0.15384615384615385, rec:1.0
# F1:0.2666666666666667 epsilon: 1.3359119668863657e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:57, fn:0
# prec: 0.14925373134328357, rec:1.0
# F1:0.2597402597402597 epsilon: 1.3496842551986443e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:57, fn:0
# prec: 0.14925373134328357, rec:1.0
# F1:0.2597402597402597 epsilon: 1.363456543510923e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:57, fn:0
# prec: 0.14925373134328357, rec:1.0
# F1:0.2597402597402597 epsilon: 1.3772288318232016e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:57, fn:0
# prec: 0.14925373134328357, rec:1.0
# F1:0.2597402597402597 epsilon: 1.3910011201354802e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:57, fn:0
# prec: 0.14925373134328357, rec:1.0
# F1:0.2597402597402597 epsilon: 1.4047734084477589e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:58, fn:0
# prec: 0.14705882352941177, rec:1.0
# F1:0.25641025641025644 epsilon: 1.4185456967600375e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:59, fn:0
# prec: 0.14492753623188406, rec:1.0
# F1:0.25316455696202533 epsilon: 1.4323179850723164e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:59, fn:0
# prec: 0.14492753623188406, rec:1.0
# F1:0.25316455696202533 epsilon: 1.446090273384595e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:59, fn:0
# prec: 0.14492753623188406, rec:1.0
# F1:0.25316455696202533 epsilon: 1.4598625616968737e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:60, fn:0
# prec: 0.14285714285714285, rec:1.0
# F1:0.25 epsilon: 1.4736348500091523e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.487407138321431e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5011794266337096e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5149517149459883e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.528724003258267e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5424962915705455e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5562685798828242e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.570040868195103e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5838131565073817e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:61, fn:0
# prec: 0.14084507042253522, rec:1.0
# F1:0.2469135802469136 epsilon: 1.5975854448196604e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:63, fn:0
# prec: 0.136986301369863, rec:1.0
# F1:0.24096385542168672 epsilon: 1.611357733131939e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:63, fn:0
# prec: 0.136986301369863, rec:1.0
# F1:0.24096385542168672 epsilon: 1.6251300214442176e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:63, fn:0
# prec: 0.136986301369863, rec:1.0
# F1:0.24096385542168672 epsilon: 1.6389023097564963e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:63, fn:0
# prec: 0.136986301369863, rec:1.0
# F1:0.24096385542168672 epsilon: 1.652674598068775e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:64, fn:0
# prec: 0.13513513513513514, rec:1.0
# F1:0.2380952380952381 epsilon: 1.6664468863810536e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:65, fn:0
# prec: 0.13333333333333333, rec:1.0
# F1:0.23529411764705882 epsilon: 1.6802191746933322e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:65, fn:0
# prec: 0.13333333333333333, rec:1.0
# F1:0.23529411764705882 epsilon: 1.6939914630056109e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:66, fn:0
# prec: 0.13157894736842105, rec:1.0
# F1:0.23255813953488372 epsilon: 1.7077637513178897e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:66, fn:0
# prec: 0.13157894736842105, rec:1.0
# F1:0.23255813953488372 epsilon: 1.7215360396301684e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:66, fn:0
# prec: 0.13157894736842105, rec:1.0
# F1:0.23255813953488372 epsilon: 1.735308327942447e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:66, fn:0
# prec: 0.13157894736842105, rec:1.0
# F1:0.23255813953488372 epsilon: 1.7490806162547257e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:66, fn:0
# prec: 0.13157894736842105, rec:1.0
# F1:0.23255813953488372 epsilon: 1.7628529045670043e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.776625192879283e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.7903974811915616e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.8041697695038402e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.817942057816119e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.8317143461283978e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.8454866344406764e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.859258922752955e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.8730312110652337e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.8868034993775123e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.900575787689791e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.9143480760020696e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:67, fn:0
# prec: 0.12987012987012986, rec:1.0
# F1:0.22988505747126434 epsilon: 1.9281203643143483e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:68, fn:0
# prec: 0.1282051282051282, rec:1.0
# F1:0.22727272727272727 epsilon: 1.941892652626627e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 1.9556649409389056e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 1.9694372292511845e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 1.983209517563463e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 1.9969818058757417e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 2.0107540941880204e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 2.024526382500299e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:69, fn:0
# prec: 0.12658227848101267, rec:1.0
# F1:0.22471910112359553 epsilon: 2.0382986708125777e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.0520709591248563e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.065843247437135e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.0796155357494136e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.0933878240616922e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.1071601123739711e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.1209324006862498e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.1347046889985284e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.148476977310807e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.1622492656230857e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.1760215539353643e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.189793842247643e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.2035661305599216e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.2173384188722003e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.231110707184479e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.244882995496758e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.2586552838090364e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.272427572121315e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.2861998604335937e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.2999721487458724e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:70, fn:0
# prec: 0.125, rec:1.0
# F1:0.2222222222222222 epsilon: 2.3137444370581515e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.32751672537043e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.341289013682709e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.3550613019949874e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.368833590307266e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.3826058786195447e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.3963781669318234e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.410150455244102e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.4239227435563806e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.4376950318686593e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.451467320180938e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.4652396084932166e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.479011896805495e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.492784185117774e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.5065564734300525e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.520328761742331e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.53410105005461e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.5478733383668884e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.561645626679167e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.5754179149914457e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.589190203303725e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.6029624916160035e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:71, fn:0
# prec: 0.12345679012345678, rec:1.0
# F1:0.21978021978021975 epsilon: 2.616734779928282e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:72, fn:0
# prec: 0.12195121951219512, rec:1.0
# F1:0.21739130434782605 epsilon: 2.630507068240561e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:72, fn:0
# prec: 0.12195121951219512, rec:1.0
# F1:0.21739130434782605 epsilon: 2.6442793565528394e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:72, fn:0
# prec: 0.12195121951219512, rec:1.0
# F1:0.21739130434782605 epsilon: 2.658051644865118e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:72, fn:0
# prec: 0.12195121951219512, rec:1.0
# F1:0.21739130434782605 epsilon: 2.6718239331773967e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:72, fn:0
# prec: 0.12195121951219512, rec:1.0
# F1:0.21739130434782605 epsilon: 2.6855962214896754e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.699368509801954e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.7131407981142326e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.7269130864265113e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.74068537473879e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.7544576630510686e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.768229951363347e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.782002239675626e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.7957745279879045e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.809546816300183e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.823319104612462e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.8370913929247404e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.8508636812370196e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.864635969549298e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.878408257861577e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.8921805461738555e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.905952834486134e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.919725122798413e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.9334974111106914e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.94726969942297e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:73, fn:0
# prec: 0.12048192771084337, rec:1.0
# F1:0.21505376344086022 epsilon: 2.9610419877352487e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:74, fn:0
# prec: 0.11904761904761904, rec:1.0
# F1:0.21276595744680848 epsilon: 2.9748142760475273e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 2.988586564359806e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.0023588526720846e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.0161311409843633e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.029903429296642e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.0436757176089206e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.057448005921199e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.071220294233478e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.0849925825457565e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.098764870858035e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.112537159170314e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.126309447482593e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.1400817357948716e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.15385402410715e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.167626312419429e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.1813986007317075e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.195170889043986e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.208943177356265e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.2227154656685434e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:75, fn:0
# prec: 0.11764705882352941, rec:1.0
# F1:0.21052631578947367 epsilon: 3.236487753980822e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.2502600422931007e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.2640323306053793e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.277804618917658e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.2915769072299366e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.3053491955422153e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.319121483854494e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.3328937721667726e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.346666060479051e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.36043834879133e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.3742106371036085e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.387982925415887e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.4017552137281663e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.415527502040445e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.4292997903527235e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.443072078665002e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.456844366977281e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.4706166552895595e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.484388943601838e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.498161231914117e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.5119335202263954e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.525705808538674e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.5394780968509527e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.5532503851632313e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.56702267347551e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.5807949617877886e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.5945672501000673e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.608339538412346e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:76, fn:0
# prec: 0.11627906976744186, rec:1.0
# F1:0.20833333333333334 epsilon: 3.6221118267246245e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:77, fn:0
# prec: 0.11494252873563218, rec:1.0
# F1:0.20618556701030927 epsilon: 3.635884115036903e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:77, fn:0
# prec: 0.11494252873563218, rec:1.0
# F1:0.20618556701030927 epsilon: 3.649656403349182e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:77, fn:0
# prec: 0.11494252873563218, rec:1.0
# F1:0.20618556701030927 epsilon: 3.663428691661461e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:77, fn:0
# prec: 0.11494252873563218, rec:1.0
# F1:0.20618556701030927 epsilon: 3.6772009799737396e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:77, fn:0
# prec: 0.11494252873563218, rec:1.0
# F1:0.20618556701030927 epsilon: 3.6909732682860182e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.704745556598297e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.7185178449105755e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.732290133222854e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.746062421535133e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.7598347098474115e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.77360699815969e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.7873792864719687e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.8011515747842474e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.814923863096526e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.8286961514088047e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.8424684397210833e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.856240728033362e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.8700130163456406e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.8837853046579192e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.897557592970198e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.9113298812824765e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:78, fn:0
# prec: 0.11363636363636363, rec:1.0
# F1:0.20408163265306123 epsilon: 3.925102169594755e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:79, fn:0
# prec: 0.11235955056179775, rec:1.0
# F1:0.20202020202020202 epsilon: 3.9388744579070343e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:79, fn:0
# prec: 0.11235955056179775, rec:1.0
# F1:0.20202020202020202 epsilon: 3.952646746219313e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:79, fn:0
# prec: 0.11235955056179775, rec:1.0
# F1:0.20202020202020202 epsilon: 3.9664190345315916e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:79, fn:0
# prec: 0.11235955056179775, rec:1.0
# F1:0.20202020202020202 epsilon: 3.98019132284387e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:79, fn:0
# prec: 0.11235955056179775, rec:1.0
# F1:0.20202020202020202 epsilon: 3.993963611156149e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.0077358994684275e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.021508187780706e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.035280476092985e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.0490527644052635e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.062825052717542e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.0765973410298207e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.0903696293420994e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.104141917654378e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.1179142059666567e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.1316864942789353e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.145458782591214e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.1592310709034926e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.173003359215771e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.18677564752805e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:80, fn:0
# prec: 0.1111111111111111, rec:1.0
# F1:0.19999999999999998 epsilon: 4.2005479358403285e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# prec: 0.10989010989010989, rec:1.0
# F1:0.198019801980198 epsilon: 4.2143202241526077e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# prec: 0.10989010989010989, rec:1.0
# F1:0.198019801980198 epsilon: 4.2280925124648863e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# prec: 0.10989010989010989, rec:1.0
# F1:0.198019801980198 epsilon: 4.241864800777165e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# prec: 0.10989010989010989, rec:1.0
# F1:0.198019801980198 epsilon: 4.2556370890894436e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# prec: 0.10989010989010989, rec:1.0
# F1:0.198019801980198 epsilon: 4.269409377401722e-16
# predcitions: [ True  True  True  True False]
# tp:10, fp:81, fn:0
# ...
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2367514905021578e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2381287193333858e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2395059481646136e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2408831769958415e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2422604058270693e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2436376346582973e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.245014863489525e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.246392092320753e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.247769321151981e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2491465499832087e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2505237788144367e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2519010076456645e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2532782364768924e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2546554653081202e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2560326941393481e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.257409922970576e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2587871518018039e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2601643806330316e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2615416094642596e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2629188382954874e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2642960671267153e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.265673295957943e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.267050524789171e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2684277536203988e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2698049824516268e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2711822112828546e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2725594401140825e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2739366689453103e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2753138977765382e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.276691126607766e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.278068355438994e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2794455842702217e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2808228131014497e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2822000419326775e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2835772707639054e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2849544995951332e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2863317284263612e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.287708957257589e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2890861860888169e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2904634149200447e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2918406437512726e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2932178725825004e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2945951014137283e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2959723302449561e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.297349559076184e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.2987267879074118e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3001040167386398e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3014812455698676e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3028584744010955e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3042357032323235e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3056129320635513e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3069901608947792e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.308367389726007e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.309744618557235e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3111218473884627e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3124990762196907e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3138763050509184e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3152535338821464e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3166307627133742e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3180079915446021e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.31938522037583e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3207624492070579e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3221396780382856e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3235169068695136e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3248941357007414e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3262713645319693e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.327648593363197e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.329025822194425e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3304030510256528e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3317802798568808e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3331575086881085e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3345347375193365e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3359119663505643e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3372891951817922e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.33866642401302e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.340043652844248e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3414208816754757e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3427981105067037e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3441753393379315e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3455525681691594e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3469297970003872e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3483070258316152e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.349684254662843e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3510614834940709e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3524387123252986e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3538159411565266e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3551931699877544e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3565703988189823e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3579476276502103e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.359324856481438e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.360702085312666e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3620793141438938e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3634565429751218e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3648337718063495e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3662110006375775e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3675882294688053e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3689654583000332e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.370342687131261e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.371719915962489e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3730971447937167e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3744743736249447e-15
# predcitions: [ True  True  True  True False]
# tp:10, fp:89, fn:0
# prec: 0.10101010101010101, rec:1.0
# F1:0.1834862385321101 epsilon: 1.3758516024561724e-15
# Best epsilon found using cross-validation: 1.377229e-18
# Best F1 on Cross Validation Set:  0.615385
# # Anomalies found: 117

# %% [markdown]
# **Expected Output**:
# <table>
#   <tr>
#     <td> <b>Best epsilon found using cross-validation: <b>  </td>
#     <td> 1.38e-18</td>
#    </tr>
#    <tr>
#     <td> <b>Best F1 on Cross Validation Set: <b>  </td>
#      <td> 0.615385 </td>
#   </tr>
#     <tr>
#     <td> <b># anomalies found: <b>  </td>
#      <td>  117 </td>
#   </tr>
# </table>

# %% [markdown]
# <details>
#   <summary><font size="2" color="darkgreen"><b>Please click here if you want to experiment with any of the non-graded code.</b></font></summary>
#     <p><i><b>Important Note: Please only do this when you've already passed the assignment to avoid problems with the autograder.</b></i>
#     <ol>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “Edit Metadata”</li>
#         <li> Hit the “Edit Metadata” button next to the code cell which you want to lock/unlock</li>
#         <li> Set the attribute value for “editable” to:
#             <ul>
#                 <li> “true” if you want to unlock it </li>
#                 <li> “false” if you want to lock it </li>
#             </ul>
#         </li>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “None” </li>
#     </ol>
#     <p> Here's a short demo of how to do the steps above:
#         <br>
#         <img src="https://lh3.google.com/u/0/d/14Xy_Mb17CZVgzVAgq7NCjMVBvSae3xO1" align="center" alt="unlock_cells.gif">
# </details>
